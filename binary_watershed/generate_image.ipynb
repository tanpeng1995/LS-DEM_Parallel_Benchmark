# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile as tif
import glob
from scipy.signal import convolve2d
import cv2
import spam.label
from skimage.restoration import denoise_nl_means, estimate_sigma
# %matplotlib inline

# %%
file_path = '/home/hasitha/Desktop/packed_img/'
img_name = 'test_1400.tif'
bin_name = 'gray_test_1400.tif'
lab_name = 'lab_test_1400.tif'

# %%
img = tif.imread(file_path+img_name)
lab = tif.imread(file_path+lab_name)
binary = tif.imread(file_path+bin_name)

# %%
idx = 303
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(img[idx]> 85,plt.cm.gray)
plt.subplot(1,3,2)
plt.imshow(binary[idx],cmap='gray')
plt.subplot(1,3,3)
plt.imshow(img[idx], plt.cm.gray)
plt.show()

# %%
plt.figure(figsize=(16,16))
plt.subplot(2,2,1)
plt.imshow(img[403],plt.cm.gray)
plt.title('case1: white spot',fontsize=16)
plt.subplot(2,2,2)
plt.imshow(img[77],plt.cm.gray)
plt.title('case2: blurry background',fontsize=16)
plt.subplot(2,2,3)
plt.imshow(lab[403],cmap=spam.label.randomCmap)
plt.title('HMRF_EM for case1',fontsize=16)
plt.subplot(2,2,4)
plt.imshow(lab[77],cmap=spam.label.randomCmap)
plt.title('HMRF_EM for case2',fontsize=16)
#plt.savefig('HMRF_EM.jpg', dpi=600, bbox_inches=None)
plt.show()
